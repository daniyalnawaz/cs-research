# %%
import http.client, urllib.parse, csv
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# Create a date range:

# %%
datelist = pd.date_range(pd.datetime(2014, 1, 1), pd.datetime(2014,12,31)).tolist()

# %% [markdown]
# Create a function that returns the HTML:

# %%
def getHTML(m, d, y):
    print('Date: ', y, m, d)
    params = urllib.parse.urlencode({'sday': d, 'mth': m, 'yr': y})
    headers = {"Content-type": "application/x-www-form-urlencoded", "Accept": "text/plain"}

    conn = http.client.HTTPConnection("dps.kse.com.pk:80")

    conn.request("POST", "/webpages/history_byDate1.php", params, headers)
    response = conn.getresponse()
    print('---', response.status, response.reason)
    
    return response.read()

# %% [markdown]
# Function to get content from a  object safely:

# %%
def getVal(dom):
    if (len(dom.contents) == 0):
        return ""
    
    val = dom.contents[0]
    
    val = val.replace(",", "")
    
    if val == None:
        return ""
    return val

# %% [markdown]
# Create an empty document:

# %%
f = open("data/2014.csv", 'a')
wr = csv.writer(f)

wr.writerow([
    'date',
    'symbol',
    'ldcp',
    'open',
    'high',
    'low',
    'closing',
    'turnover'
])
# Out:
# 49

# %%
for date in datelist:
    html = getHTML("{0:0=2d}".format(date.month), "{0:0=2d}".format(date.day), date.year)
    soup = BeautifulSoup(html, "html.parser")
    rows = soup.find_all('tr')
    count = 0
    
    for row in rows:
        tds = row.find_all('td')
        if len(tds) != 7:
            continue
    
        link = tds[0].find('a')
        if link == None:
            continue
        
        wr.writerow([
            date.strftime("%Y-%m-%d"),
            getVal(link),
            getVal(tds[1]),
            getVal(tds[2]),
            getVal(tds[3]),
            getVal(tds[4]),
            getVal(tds[5]),
            getVal(tds[6])
        ])
        
        count = count + 1
    
    print('---', 'Total Values:', count)

f.close()
# Out:
# Date:  2014 01 01
# --- 200 OK
# --- Total Values: 538
# Date:  2014 01 02
# --- 200 OK
# --- Total Values: 537
# Date:  2014 01 03
# --- 200 OK
# --- Total Values: 532
# Date:  2014 01 04
# --- 200 OK
# --- Total Values: 0
# Date:  2014 01 05
# --- 200 OK
# --- Total Values: 0
# Date:  2014 01 06
# --- 200 OK
# --- Total Values: 545
# Date:  2014 01 07
# --- 200 OK
# --- Total Values: 536
# Date:  2014 01 08
# --- 200 OK
# --- Total Values: 548
# Date:  2014 01 09
# --- 200 OK
# --- Total Values: 549
# Date:  2014 01 10
# --- 200 OK
# --- Total Values: 520
# Date:  2014 01 11
# --- 200 OK
# --- Total Values: 0
# Date:  2014 01 12
# --- 200 OK
# --- Total Values: 0
# Date:  2014 01 13
# --- 200 OK
# --- Total Values: 545
# Date:  2014 01 14
# --- 200 OK
# --- Total Values: 0
# Date:  2014 01 15
# --- 200 OK
# --- Total Values: 552
# Date:  2014 01 16
# --- 200 OK
# --- Total Values: 547
# Date:  2014 01 17
# --- 200 OK
# --- Total Values: 534
# Date:  2014 01 18
# --- 200 OK
# --- Total Values: 0
# Date:  2014 01 19
# --- 200 OK
# --- Total Values: 0
# Date:  2014 01 20
# --- 200 OK
# --- Total Values: 537
# Date:  2014 01 21
# --- 200 OK
# --- Total Values: 553
# Date:  2014 01 22
# --- 200 OK
# --- Total Values: 558
# Date:  2014 01 23
# --- 200 OK
# --- Total Values: 560
# Date:  2014 01 24
# --- 200 OK
# --- Total Values: 550
# Date:  2014 01 25
# --- 200 OK
# --- Total Values: 0
# Date:  2014 01 26
# --- 200 OK
# --- Total Values: 0
# Date:  2014 01 27
# --- 200 OK
# --- Total Values: 587
# Date:  2014 01 28
# --- 200 OK
# --- Total Values: 579
# Date:  2014 01 29
# --- 200 OK
# --- Total Values: 569
# Date:  2014 01 30
# --- 200 OK
# --- Total Values: 571
# Date:  2014 01 31
# --- 200 OK
# --- Total Values: 574
# Date:  2014 02 01
# --- 200 OK
# --- Total Values: 0
# Date:  2014 02 02
# --- 200 OK
# --- Total Values: 0
# Date:  2014 02 03
# --- 200 OK
# --- Total Values: 538
# Date:  2014 02 04
# --- 200 OK
# --- Total Values: 515
# Date:  2014 02 05
# --- 200 OK
# --- Total Values: 0
# Date:  2014 02 06
# --- 200 OK
# --- Total Values: 536
# Date:  2014 02 07
# --- 200 OK
# --- Total Values: 513
# Date:  2014 02 08
# --- 200 OK
# --- Total Values: 0
# Date:  2014 02 09
# --- 200 OK
# --- Total Values: 0
# Date:  2014 02 10
# --- 200 OK
# --- Total Values: 529
# Date:  2014 02 11
# --- 200 OK
# --- Total Values: 524
# Date:  2014 02 12
# --- 200 OK
# --- Total Values: 537
# Date:  2014 02 13
# --- 200 OK
# --- Total Values: 523
# Date:  2014 02 14
# --- 200 OK
# --- Total Values: 516
# Date:  2014 02 15
# --- 200 OK
# --- Total Values: 0
# Date:  2014 02 16
# --- 200 OK
# --- Total Values: 0
# Date:  2014 02 17
# --- 200 OK
# --- Total Values: 515
# Date:  2014 02 18
# --- 200 OK
# --- Total Values: 519
# Date:  2014 02 19
# --- 200 OK
# --- Total Values: 507
# Date:  2014 02 20
# --- 200 OK
# --- Total Values: 496
# Date:  2014 02 21
# --- 200 OK
# --- Total Values: 505
# Date:  2014 02 22
# --- 200 OK
# --- Total Values: 0
# Date:  2014 02 23
# --- 200 OK
# --- Total Values: 0
# Date:  2014 02 24
# --- 200 OK
# --- Total Values: 534
# Date:  2014 02 25
# --- 200 OK
# --- Total Values: 533
# Date:  2014 02 26
# --- 200 OK
# --- Total Values: 548
# Date:  2014 02 27
# --- 200 OK
# --- Total Values: 541
# Date:  2014 02 28
# --- 200 OK
# --- Total Values: 535
# Date:  2014 03 01
# --- 200 OK
# --- Total Values: 0
# Date:  2014 03 02
# --- 200 OK
# --- Total Values: 0
# Date:  2014 03 03
# --- 200 OK
# --- Total Values: 507
# Date:  2014 03 04
# --- 200 OK
# --- Total Values: 512
# Date:  2014 03 05
# --- 200 OK
# --- Total Values: 524
# Date:  2014 03 06
# --- 200 OK
# --- Total Values: 527
# Date:  2014 03 07
# --- 200 OK
# --- Total Values: 503
# Date:  2014 03 08
# --- 200 OK
# --- Total Values: 0
# Date:  2014 03 09
# --- 200 OK
# --- Total Values: 0
# Date:  2014 03 10
# --- 200 OK
# --- Total Values: 526
# Date:  2014 03 11
# --- 200 OK
# --- Total Values: 535
# Date:  2014 03 12
# --- 200 OK
# --- Total Values: 528
# Date:  2014 03 13
# --- 200 OK
# --- Total Values: 511
# Date:  2014 03 14
# --- 200 OK
# --- Total Values: 512
# Date:  2014 03 15
# --- 200 OK
# --- Total Values: 0
# Date:  2014 03 16
# --- 200 OK
# --- Total Values: 0
# Date:  2014 03 17
# --- 200 OK
# --- Total Values: 516
# Date:  2014 03 18
# --- 200 OK
# --- Total Values: 512
# Date:  2014 03 19
# --- 200 OK
# --- Total Values: 501
# Date:  2014 03 20
# --- 200 OK
# --- Total Values: 510
# Date:  2014 03 21
# --- 200 OK
# --- Total Values: 487
# Date:  2014 03 22
# --- 200 OK
# --- Total Values: 0
# Date:  2014 03 23
# --- 200 OK
# --- Total Values: 0
# Date:  2014 03 24
# --- 200 OK
# --- Total Values: 527
# Date:  2014 03 25
# --- 200 OK
# --- Total Values: 513
# Date:  2014 03 26
# --- 200 OK
# --- Total Values: 544
# Date:  2014 03 27
# --- 200 OK
# --- Total Values: 554
# Date:  2014 03 28
# --- 200 OK
# --- Total Values: 529
# Date:  2014 03 29
# --- 200 OK
# --- Total Values: 0
# Date:  2014 03 30
# --- 200 OK
# --- Total Values: 0
# Date:  2014 03 31
# --- 200 OK
# --- Total Values: 503
# Date:  2014 04 01
# --- 200 OK
# --- Total Values: 512
# Date:  2014 04 02
# --- 200 OK
# --- Total Values: 522
# Date:  2014 04 03
# --- 200 OK
# --- Total Values: 531
# Date:  2014 04 04
# --- 200 OK
# --- Total Values: 517
# Date:  2014 04 05
# --- 200 OK
# --- Total Values: 0
# Date:  2014 04 06
# --- 200 OK
# --- Total Values: 0
# Date:  2014 04 07
# --- 200 OK
# --- Total Values: 513
# Date:  2014 04 08
# --- 200 OK
# --- Total Values: 519
# Date:  2014 04 09
# --- 200 OK
# --- Total Values: 520
# Date:  2014 04 10
# --- 200 OK
# --- Total Values: 533
# Date:  2014 04 11
# --- 200 OK
# --- Total Values: 512
# Date:  2014 04 12
# --- 200 OK
# --- Total Values: 0
# Date:  2014 04 13
# --- 200 OK
# --- Total Values: 0
# Date:  2014 04 14
# --- 200 OK
# --- Total Values: 523
# Date:  2014 04 15
# --- 200 OK
# --- Total Values: 506
# Date:  2014 04 16
# --- 200 OK
# --- Total Values: 525
# Date:  2014 04 17
# --- 200 OK
# --- Total Values: 515
# Date:  2014 04 18
# --- 200 OK
# --- Total Values: 534
# Date:  2014 04 19
# --- 200 OK
# --- Total Values: 0
# Date:  2014 04 20
# --- 200 OK
# --- Total Values: 0
# Date:  2014 04 21
# --- 200 OK
# --- Total Values: 540
# Date:  2014 04 22
# --- 200 OK
# --- Total Values: 541
# Date:  2014 04 23
# --- 200 OK
# --- Total Values: 552
# Date:  2014 04 24
# --- 200 OK
# --- Total Values: 537
# Date:  2014 04 25
# --- 200 OK
# --- Total Values: 538
# Date:  2014 04 26
# --- 200 OK
# --- Total Values: 0
# Date:  2014 04 27
# --- 200 OK
# --- Total Values: 0
# Date:  2014 04 28
# --- 200 OK
# --- Total Values: 493
# Date:  2014 04 29
# --- 200 OK
# --- Total Values: 514
# Date:  2014 04 30
# --- 200 OK
# --- Total Values: 506
# Date:  2014 05 01
# --- 200 OK
# --- Total Values: 0
# Date:  2014 05 02
# --- 200 OK
# --- Total Values: 509
# Date:  2014 05 03
# --- 200 OK
# --- Total Values: 0
# Date:  2014 05 04
# --- 200 OK
# --- Total Values: 0
# Date:  2014 05 05
# --- 200 OK
# --- Total Values: 503
# Date:  2014 05 06
# --- 200 OK
# --- Total Values: 494
# Date:  2014 05 07
# --- 200 OK
# --- Total Values: 483
# Date:  2014 05 08
# --- 200 OK
# --- Total Values: 496
# Date:  2014 05 09
# --- 200 OK
# --- Total Values: 489
# Date:  2014 05 10
# --- 200 OK
# --- Total Values: 0
# Date:  2014 05 11
# --- 200 OK
# --- Total Values: 0
# Date:  2014 05 12
# --- 200 OK
# --- Total Values: 505
# Date:  2014 05 13
# --- 200 OK
# --- Total Values: 488
# Date:  2014 05 14
# --- 200 OK
# --- Total Values: 505
# Date:  2014 05 15
# --- 200 OK
# --- Total Values: 520
# Date:  2014 05 16
# --- 200 OK
# --- Total Values: 523
# Date:  2014 05 17
# --- 200 OK
# --- Total Values: 0
# Date:  2014 05 18
# --- 200 OK
# --- Total Values: 0
# Date:  2014 05 19
# --- 200 OK
# --- Total Values: 502
# Date:  2014 05 20
# --- 200 OK
# --- Total Values: 519
# Date:  2014 05 21
# --- 200 OK
# --- Total Values: 513
# Date:  2014 05 22
# --- 200 OK
# --- Total Values: 503
# Date:  2014 05 23
# --- 200 OK
# --- Total Values: 491
# Date:  2014 05 24
# --- 200 OK
# --- Total Values: 0
# Date:  2014 05 25
# --- 200 OK
# --- Total Values: 0
# Date:  2014 05 26
# --- 200 OK
# --- Total Values: 534
# Date:  2014 05 27
# --- 200 OK
# --- Total Values: 556
# Date:  2014 05 28
# --- 200 OK
# --- Total Values: 566
# Date:  2014 05 29
# --- 200 OK
# --- Total Values: 572
# Date:  2014 05 30
# --- 200 OK
# --- Total Values: 559
# Date:  2014 05 31
# --- 200 OK
# --- Total Values: 0
# Date:  2014 06 01
# --- 200 OK
# --- Total Values: 0
# Date:  2014 06 02
# --- 200 OK
# --- Total Values: 522
# Date:  2014 06 03
# --- 200 OK
# --- Total Values: 536
# Date:  2014 06 04
# --- 200 OK
# --- Total Values: 523
# Date:  2014 06 05
# --- 200 OK
# --- Total Values: 518
# Date:  2014 06 06
# --- 200 OK
# --- Total Values: 494
# Date:  2014 06 07
# --- 200 OK
# --- Total Values: 0
# Date:  2014 06 08
# --- 200 OK
# --- Total Values: 0
# Date:  2014 06 09
# --- 200 OK
# --- Total Values: 500
# Date:  2014 06 10
# --- 200 OK
# --- Total Values: 512
# Date:  2014 06 11
# --- 200 OK
# --- Total Values: 524
# Date:  2014 06 12
# --- 200 OK
# --- Total Values: 497
# Date:  2014 06 13
# --- 200 OK
# --- Total Values: 503
# Date:  2014 06 14
# --- 200 OK
# --- Total Values: 0
# Date:  2014 06 15
# --- 200 OK
# --- Total Values: 0
# Date:  2014 06 16
# --- 200 OK
# --- Total Values: 494
# Date:  2014 06 17
# --- 200 OK
# --- Total Values: 498
# Date:  2014 06 18
# --- 200 OK
# --- Total Values: 489
# Date:  2014 06 19
# --- 200 OK
# --- Total Values: 516
# Date:  2014 06 20
# --- 200 OK
# --- Total Values: 474
# Date:  2014 06 21
# --- 200 OK
# --- Total Values: 0
# Date:  2014 06 22
# --- 200 OK
# --- Total Values: 0
# Date:  2014 06 23
# --- 200 OK
# --- Total Values: 508
# Date:  2014 06 24
# --- 200 OK
# --- Total Values: 537
# Date:  2014 06 25
# --- 200 OK
# --- Total Values: 543
# Date:  2014 06 26
# --- 200 OK
# --- Total Values: 513
# Date:  2014 06 27
# --- 200 OK
# --- Total Values: 520
# Date:  2014 06 28
# --- 200 OK
# --- Total Values: 0
# Date:  2014 06 29
# --- 200 OK
# --- Total Values: 0
# Date:  2014 06 30
# --- 200 OK
# --- Total Values: 471
# Date:  2014 07 01
# --- 200 OK
# --- Total Values: 443
# Date:  2014 07 02
# --- 200 OK
# --- Total Values: 474
# Date:  2014 07 03
# --- 200 OK
# --- Total Values: 452
# Date:  2014 07 04
# --- 200 OK
# --- Total Values: 468
# Date:  2014 07 05
# --- 200 OK
# --- Total Values: 0
# Date:  2014 07 06
# --- 200 OK
# --- Total Values: 0
# Date:  2014 07 07
# --- 200 OK
# --- Total Values: 461
# Date:  2014 07 08
# --- 200 OK
# --- Total Values: 446
# Date:  2014 07 09
# --- 200 OK
# --- Total Values: 452
# Date:  2014 07 10
# --- 200 OK
# --- Total Values: 449
# Date:  2014 07 11
# --- 200 OK
# --- Total Values: 434
# Date:  2014 07 12
# --- 200 OK
# --- Total Values: 0
# Date:  2014 07 13
# --- 200 OK
# --- Total Values: 0
# Date:  2014 07 14
# --- 200 OK
# --- Total Values: 472
# Date:  2014 07 15
# --- 200 OK
# --- Total Values: 478
# Date:  2014 07 16
# --- 200 OK
# --- Total Values: 482
# Date:  2014 07 17
# --- 200 OK
# --- Total Values: 489
# Date:  2014 07 18
# --- 200 OK
# --- Total Values: 467
# Date:  2014 07 19
# --- 200 OK
# --- Total Values: 0
# Date:  2014 07 20
# --- 200 OK
# --- Total Values: 0
# Date:  2014 07 21
# --- 200 OK
# --- Total Values: 519
# Date:  2014 07 22
# --- 200 OK
# --- Total Values: 515
# Date:  2014 07 23
# --- 200 OK
# --- Total Values: 502
# Date:  2014 07 24
# --- 200 OK
# --- Total Values: 502
# Date:  2014 07 25
# --- 200 OK
# --- Total Values: 0
# Date:  2014 07 26
# --- 200 OK
# --- Total Values: 0
# Date:  2014 07 27
# --- 200 OK
# --- Total Values: 0
# Date:  2014 07 28
# --- 200 OK
# --- Total Values: 436
# Date:  2014 07 29
# --- 200 OK
# --- Total Values: 0
# Date:  2014 07 30
# --- 200 OK
# --- Total Values: 0
# Date:  2014 07 31
# --- 200 OK
# --- Total Values: 0
# Date:  2014 08 01
# --- 200 OK
# --- Total Values: 0
# Date:  2014 08 02
# --- 200 OK
# --- Total Values: 0
# Date:  2014 08 03
# --- 200 OK
# --- Total Values: 0
# Date:  2014 08 04
# --- 200 OK
# --- Total Values: 485
# Date:  2014 08 05
# --- 200 OK
# --- Total Values: 469
# Date:  2014 08 06
# --- 200 OK
# --- Total Values: 462
# Date:  2014 08 07
# --- 200 OK
# --- Total Values: 467
# Date:  2014 08 08
# --- 200 OK
# --- Total Values: 461
# Date:  2014 08 09
# --- 200 OK
# --- Total Values: 0
# Date:  2014 08 10
# --- 200 OK
# --- Total Values: 0
# Date:  2014 08 11
# --- 200 OK
# --- Total Values: 497
# Date:  2014 08 12
# --- 200 OK
# --- Total Values: 495
# Date:  2014 08 13
# --- 200 OK
# --- Total Values: 476
# Date:  2014 08 14
# --- 200 OK
# --- Total Values: 0
# Date:  2014 08 15
# --- 200 OK
# --- Total Values: 465
# Date:  2014 08 16
# --- 200 OK
# --- Total Values: 0
# Date:  2014 08 17
# --- 200 OK
# --- Total Values: 0
# Date:  2014 08 18
# --- 200 OK
# --- Total Values: 460
# Date:  2014 08 19
# --- 200 OK
# --- Total Values: 474
# Date:  2014 08 20
# --- 200 OK
# --- Total Values: 452
# Date:  2014 08 21
# --- 200 OK
# --- Total Values: 498
# Date:  2014 08 22
# --- 200 OK
# --- Total Values: 434
# Date:  2014 08 23
# --- 200 OK
# --- Total Values: 0
# Date:  2014 08 24
# --- 200 OK
# --- Total Values: 0
# Date:  2014 08 25
# --- 200 OK
# --- Total Values: 461
# Date:  2014 08 26
# --- 200 OK
# --- Total Values: 483
# Date:  2014 08 27
# --- 200 OK
# --- Total Values: 502
# Date:  2014 08 28
# --- 200 OK
# --- Total Values: 476
# Date:  2014 08 29
# --- 200 OK
# --- Total Values: 523
# Date:  2014 08 30
# --- 200 OK
# --- Total Values: 0
# Date:  2014 08 31
# --- 200 OK
# --- Total Values: 0
# Date:  2014 09 01
# --- 200 OK
# --- Total Values: 445
# Date:  2014 09 02
# --- 200 OK
# --- Total Values: 487
# Date:  2014 09 03
# --- 200 OK
# --- Total Values: 506
# Date:  2014 09 04
# --- 200 OK
# --- Total Values: 514
# Date:  2014 09 05
# --- 200 OK
# --- Total Values: 489
# Date:  2014 09 06
# --- 200 OK
# --- Total Values: 0
# Date:  2014 09 07
# --- 200 OK
# --- Total Values: 0
# Date:  2014 09 08
# --- 200 OK
# --- Total Values: 517
# Date:  2014 09 09
# --- 200 OK
# --- Total Values: 524
# Date:  2014 09 10
# --- 200 OK
# --- Total Values: 510
# Date:  2014 09 11
# --- 200 OK
# --- Total Values: 525
# Date:  2014 09 12
# --- 200 OK
# --- Total Values: 530
# Date:  2014 09 13
# --- 200 OK
# --- Total Values: 0
# Date:  2014 09 14
# --- 200 OK
# --- Total Values: 0
# Date:  2014 09 15
# --- 200 OK
# --- Total Values: 521
# Date:  2014 09 16
# --- 200 OK
# --- Total Values: 528
# Date:  2014 09 17
# --- 200 OK
# --- Total Values: 526
# Date:  2014 09 18
# --- 200 OK
# --- Total Values: 520
# Date:  2014 09 19
# --- 200 OK
# --- Total Values: 535
# Date:  2014 09 20
# --- 200 OK
# --- Total Values: 0
# Date:  2014 09 21
# --- 200 OK
# --- Total Values: 0
# Date:  2014 09 22
# --- 200 OK
# --- Total Values: 571
# Date:  2014 09 23
# --- 200 OK
# --- Total Values: 587
# Date:  2014 09 24
# --- 200 OK
# --- Total Values: 593
# Date:  2014 09 25
# --- 200 OK
# --- Total Values: 578
# Date:  2014 09 26
# --- 200 OK
# --- Total Values: 580
# Date:  2014 09 27
# --- 200 OK
# --- Total Values: 0
# Date:  2014 09 28
# --- 200 OK
# --- Total Values: 0
# Date:  2014 09 29
# --- 200 OK
# --- Total Values: 535
# Date:  2014 09 30
# --- 200 OK
# --- Total Values: 516
# Date:  2014 10 01
# --- 200 OK
# --- Total Values: 533
# Date:  2014 10 02
# --- 200 OK
# --- Total Values: 524
# Date:  2014 10 03
# --- 200 OK
# --- Total Values: 521
# Date:  2014 10 04
# --- 200 OK
# --- Total Values: 0
# Date:  2014 10 05
# --- 200 OK
# --- Total Values: 0
# Date:  2014 10 06
# --- 200 OK
# --- Total Values: 0
# Date:  2014 10 07
# --- 200 OK
# --- Total Values: 0
# Date:  2014 10 08
# --- 200 OK
# --- Total Values: 0
# Date:  2014 10 09
# --- 200 OK
# --- Total Values: 520
# Date:  2014 10 10
# --- 200 OK
# --- Total Values: 558
# Date:  2014 10 11
# --- 200 OK
# --- Total Values: 0
# Date:  2014 10 12
# --- 200 OK
# --- Total Values: 0
# Date:  2014 10 13
# --- 200 OK
# --- Total Values: 568
# Date:  2014 10 14
# --- 200 OK
# --- Total Values: 552
# Date:  2014 10 15
# --- 200 OK
# --- Total Values: 550
# Date:  2014 10 16
# --- 200 OK
# --- Total Values: 551
# Date:  2014 10 17
# --- 200 OK
# --- Total Values: 543
# Date:  2014 10 18
# --- 200 OK
# --- Total Values: 0
# Date:  2014 10 19
# --- 200 OK
# --- Total Values: 0
# Date:  2014 10 20
# --- 200 OK
# --- Total Values: 520
# Date:  2014 10 21
# --- 200 OK
# --- Total Values: 538
# Date:  2014 10 22
# --- 200 OK
# --- Total Values: 527
# Date:  2014 10 23
# --- 200 OK
# --- Total Values: 546
# Date:  2014 10 24
# --- 200 OK
# --- Total Values: 524
# Date:  2014 10 25
# --- 200 OK
# --- Total Values: 0
# Date:  2014 10 26
# --- 200 OK
# --- Total Values: 0
# Date:  2014 10 27
# --- 200 OK
# --- Total Values: 566
# Date:  2014 10 28
# --- 200 OK
# --- Total Values: 578
# Date:  2014 10 29
# --- 200 OK
# --- Total Values: 574
# Date:  2014 10 30
# --- 200 OK
# --- Total Values: 574
# Date:  2014 10 31
# --- 200 OK
# --- Total Values: 565
# Date:  2014 11 01
# --- 200 OK
# --- Total Values: 0
# Date:  2014 11 02
# --- 200 OK
# --- Total Values: 0
# Date:  2014 11 03
# --- 200 OK
# --- Total Values: 0
# Date:  2014 11 04
# --- 200 OK
# --- Total Values: 0
# Date:  2014 11 05
# --- 200 OK
# --- Total Values: 548
# Date:  2014 11 06
# --- 200 OK
# --- Total Values: 545
# Date:  2014 11 07
# --- 200 OK
# --- Total Values: 560
# Date:  2014 11 08
# --- 200 OK
# --- Total Values: 0
# Date:  2014 11 09
# --- 200 OK
# --- Total Values: 0
# Date:  2014 11 10
# --- 200 OK
# --- Total Values: 562
# Date:  2014 11 11
# --- 200 OK
# --- Total Values: 562
# Date:  2014 11 12
# --- 200 OK
# --- Total Values: 576
# Date:  2014 11 13
# --- 200 OK
# --- Total Values: 570
# Date:  2014 11 14
# --- 200 OK
# --- Total Values: 546
# Date:  2014 11 15
# --- 200 OK
# --- Total Values: 0
# Date:  2014 11 16
# --- 200 OK
# --- Total Values: 0
# Date:  2014 11 17
# --- 200 OK
# --- Total Values: 554
# Date:  2014 11 18
# --- 200 OK
# --- Total Values: 534
# Date:  2014 11 19
# --- 200 OK
# --- Total Values: 537
# Date:  2014 11 20
# --- 200 OK
# --- Total Values: 536
# Date:  2014 11 21
# --- 200 OK
# --- Total Values: 516
# Date:  2014 11 22
# --- 200 OK
# --- Total Values: 0
# Date:  2014 11 23
# --- 200 OK
# --- Total Values: 0
# Date:  2014 11 24
# --- 200 OK
# --- Total Values: 550
# Date:  2014 11 25
# --- 200 OK
# --- Total Values: 549
# Date:  2014 11 26
# --- 200 OK
# --- Total Values: 563
# Date:  2014 11 27
# --- 200 OK
# --- Total Values: 566
# Date:  2014 11 28
# --- 200 OK
# --- Total Values: 555
# Date:  2014 11 29
# --- 200 OK
# --- Total Values: 0
# Date:  2014 11 30
# --- 200 OK
# --- Total Values: 0
# Date:  2014 12 01
# --- 200 OK
# --- Total Values: 513
# Date:  2014 12 02
# --- 200 OK
# --- Total Values: 546
# Date:  2014 12 03
# --- 200 OK
# --- Total Values: 557
# Date:  2014 12 04
# --- 200 OK
# --- Total Values: 551
# Date:  2014 12 05
# --- 200 OK
# --- Total Values: 545
# Date:  2014 12 06
# --- 200 OK
# --- Total Values: 0
# Date:  2014 12 07
# --- 200 OK
# --- Total Values: 0
# Date:  2014 12 08
# --- 200 OK
# --- Total Values: 515
# Date:  2014 12 09
# --- 200 OK
# --- Total Values: 526
# Date:  2014 12 10
# --- 200 OK
# --- Total Values: 531
# Date:  2014 12 11
# --- 200 OK
# --- Total Values: 521
# Date:  2014 12 12
# --- 200 OK
# --- Total Values: 502
# Date:  2014 12 13
# --- 200 OK
# --- Total Values: 0
# Date:  2014 12 14
# --- 200 OK
# --- Total Values: 0
# Date:  2014 12 15
# --- 200 OK
# --- Total Values: 502
# Date:  2014 12 16
# --- 200 OK
# --- Total Values: 537
# Date:  2014 12 17
# --- 200 OK
# --- Total Values: 500
# Date:  2014 12 18
# --- 200 OK
# --- Total Values: 520
# Date:  2014 12 19
# --- 200 OK
# --- Total Values: 511
# Date:  2014 12 20
# --- 200 OK
# --- Total Values: 0
# Date:  2014 12 21
# --- 200 OK
# --- Total Values: 0
# Date:  2014 12 22
# --- 200 OK
# --- Total Values: 536
# Date:  2014 12 23
# --- 200 OK
# --- Total Values: 563
# Date:  2014 12 24
# --- 200 OK
# --- Total Values: 569
# Date:  2014 12 25
# --- 200 OK
# --- Total Values: 0
# Date:  2014 12 26
# --- 200 OK
# --- Total Values: 540
# Date:  2014 12 27
# --- 200 OK
# --- Total Values: 0
# Date:  2014 12 28
# --- 200 OK
# --- Total Values: 0
# Date:  2014 12 29
# --- 200 OK
# --- Total Values: 500
# Date:  2014 12 30
# --- 200 OK
# --- Total Values: 513
# Date:  2014 12 31
# --- 200 OK
# --- Total Values: 520
